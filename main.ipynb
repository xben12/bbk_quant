# %%
from lib_book import Book
from lib_evaluate import InvestPerformance
import matplotlib.pyplot as plt

import pandas as pd

mb = Book('btc')

ip = InvestPerformance()
df_bk = mb.run_strategy( '2021-01-01', '2023-12-31', invest_amt  = 1000, mmt_list = [30], vlt_list = [7, 180])
df_orders = mb.orders.df_orders
df_orders.to_clipboard()
print(df_orders)

df_bk[[ 'cstrategy', 'creturns']].plot()
plt.show()
# Out:
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:113: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '11.360472864595181' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.df_orders.loc[order_id] = order_row
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:113: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-51.430939231185675' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.df_orders.loc[order_id] = order_row
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['highest_ptf_v'] = highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['max_pnl'] = highest_ptf_v - entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# ...
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_date'] = date
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_price'] = price_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['last_ptf_v'] = ptf_v_T
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['order_drawdown'] = ptf_v_T - highest_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['running_pnl'] =  ptf_v_T -  entry_ptf_v
# /Users/benliu/Documents/Learn_Web3/bbk_quant/lib_order.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order['b_closed'] =  order['order_drawdown'] < stop_loss_limit
#     order_id  long_short      size  b_closed entry_comments  pos_scale  \
# 0          0           1  0.034456      True                  1.000000
# 1          1           1  0.031861      True                  1.000000
# 2          2           1  0.034298      True                  1.000000
# 3          3           1  0.034802      True                  1.000000
# 4          4           1  0.031865      True                  0.976157
# ..       ...         ...       ...       ...            ...        ...
# 81        81          -1  0.099897      True                  1.000000
# 82        82           1  0.091528      True                  1.000000
# 83        83           1  0.085833      True                  1.000000
# 84        84           1  0.082398      True                  1.000000
# 85        85           1  0.081901     False                  1.000000
#
#    entry_date highest_ptf_date            last_date   entry_price  \
# 0  2021-01-01       2021-01-04  2021-01-05 00:00:00  29022.418395
# 1  2021-01-06       2021-01-09  2021-01-11 00:00:00  34082.206049
# 2  2021-01-12       2021-01-15  2021-01-16 00:00:00  35669.906687
# 3  2021-01-17       2021-01-19  2021-01-22 00:00:00  36254.713079
# 4  2021-01-23       2021-01-23  2021-01-28 00:00:00  32957.908783
# ..        ...              ...                  ...           ...
# 81 2023-09-16       2023-09-27  2023-10-02 00:00:00  26634.631025
# 82 2023-10-03       2023-11-11  2023-11-15 00:00:00  27615.064885
# 83 2023-11-16       2023-11-16  2023-11-22 00:00:00  37903.662452
# 84 2023-11-23       2023-12-09  2023-12-12 00:00:00  37464.832932
# 85 2023-12-13       2023-12-23  2023-12-31 00:00:00  41450.819387
#
#     highest_ptf_price    last_price  entry_ptf_v  highest_ptf_v   last_ptf_v  \
# 0        33008.226203  31515.575967  1000.000000    1137.335482  1085.904542
# 1        40815.961855  38397.895985  1085.904542    1300.450984  1223.408180
# 2        39232.749971  36787.521217  1223.408180    1345.606751  1261.740177
# 3        36595.464769  30913.695736  1261.740177    1273.599052  1075.861553
# 4        32957.908783  30445.525865  1050.210025    1050.210025   970.152466
# ..                ...           ...          ...            ...          ...
# 81       26204.757591  27967.510579 -2660.708222   -2617.765342 -2793.858315
# 82       37344.249001  35545.201433  2527.558130    3418.053173  3253.389526
# 83       37903.662452  35965.360361  3253.389526    3253.389526  3087.019014
# 84       44202.176109  41200.962726  3087.019014    3642.161126  3394.867810
# 85       44003.696022  42220.611401  3394.867810    3603.951221  3457.914625
#
#     order_drawdown     max_pnl  running_pnl  stop_loss_limit
# 0       -51.430939  137.335482    85.904542       -50.000000
# 1       -77.042804  214.546441   137.503637       -54.295227
# 2       -83.866574  122.198571    38.331997       -61.170409
# 3      -197.737498   11.858875  -185.878624       -63.087009
# 4       -80.057559    0.000000   -80.057559       -53.793078
# ..             ...         ...          ...              ...
# 81     -176.092973   42.942881  -133.150093      -133.035411
# 82     -164.663647  890.495043   725.831396      -126.377906
# 83     -166.370512    0.000000  -166.370512      -162.669476
# 84     -247.293316  555.142112   307.848796      -154.350951
# 85     -146.036596  209.083411    63.046815      -169.743391
#
# [86 rows x 19 columns]
